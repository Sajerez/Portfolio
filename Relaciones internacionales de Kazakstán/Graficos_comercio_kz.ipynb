# %% [markdown]
# Los siguientes gráficos fueron realizados en el marco de la redacción de un paper sobre las relaciones internacionales entre Kazakstán y Rusia y Kazakstán y Occidente. Parte de la información fue extraída del Observatorio de Complejidad Económica, mientras que el último fue extraído de papers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size']='8'
df2022=pd.read_csv("https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/2022.csv", sep=",")
df2015=pd.read_csv("https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/2015.csv", sep=",")
df2022
# Out:
#         Continent Continent ID               Country Country ID ISO 3  \
# 0            Asia           as  United Arab Emirates      asare   are
# 1            Asia           as            Azerbaijan      asaze   aze
# 2            Asia           as                Brunei      asbrn   brn
# 3            Asia           as                 China      aschn   chn
# 4            Asia           as                 India      asind   ind
# 5            Asia           as                Israel      asisr   isr
# 6            Asia           as                 Japan      asjpn   jpn
# 7            Asia           as            Kyrgyzstan      askgz   kgz
# 8            Asia           as           South Korea      askor   kor
# 9            Asia           as             Singapore      assgp   sgp
# 10           Asia           as              Thailand      astha   tha
# 11           Asia           as                Turkey      astur   tur
# 12           Asia           as            Uzbekistan      asuzb   uzb
# 13         Europe           eu               Austria      euaut   aut
# 14         Europe           eu              Bulgaria      eubgr   bgr
# 15         Europe           eu           Switzerland      euche   che
# 16         Europe           eu               Czechia      eucze   cze
# 17         Europe           eu               Germany      eudeu   deu
# 18         Europe           eu                 Spain      euesp   esp
# 19         Europe           eu               Estonia      euest   est
# 20         Europe           eu               Finland      eufin   fin
# 21         Europe           eu                France      eufra   fra
# 22         Europe           eu        United Kingdom      eugbr   gbr
# 23         Europe           eu             Gibraltar      eugib   gib
# 24         Europe           eu                Greece      eugrc   grc
# 25         Europe           eu               Croatia      euhrv   hrv
# 26         Europe           eu               Hungary      euhun   hun
# 27         Europe           eu                 Italy      euita   ita
# 28         Europe           eu             Lithuania      eultu   ltu
# 29         Europe           eu                 Malta      eumlt   mlt
# 30         Europe           eu           Netherlands      eunld   nld
# 31         Europe           eu                Poland      eupol   pol
# 32         Europe           eu               Romania      eurou   rou
# 33         Europe           eu                Russia      eurus   rus
# 34         Europe           eu              Slovakia      eusvk   svk
# 35  North America           na                Panama      napan   pan
# 36  North America           na         United States      nausa   usa
#
#      Trade Value  Trade Value Growth  Trade Value Growth Value  Year
# 0   2.496225e+08            2.689552              1.819659e+08  2022
# 1   7.475568e+07                 NaN                       NaN  2022
# 2   5.396681e+08           -0.391758             -3.475908e+08  2022
# 3   4.102964e+09            1.202370              2.239987e+09  2022
# 4   1.697604e+09            0.111243              1.699414e+08  2022
# 5   7.765701e+08            2.868801              5.758438e+08  2022
# 6   7.867198e+07            0.058120              4.321230e+06  2022
# 7   5.762250e+05            0.874585              2.688370e+05  2022
# 8   4.393006e+09            1.586222              2.694386e+09  2022
# 9   1.811498e+09            0.631146              7.009302e+08  2022
# 10  3.523136e+07                 NaN                       NaN  2022
# 11  2.898124e+09            0.737171              1.229823e+09  2022
# 12  5.646707e+07            0.963288              2.770559e+07  2022
# 13  1.430789e+09            0.008821              1.251054e+07  2022
# 14  5.017184e+07           -0.825056             -2.366161e+08  2022
# 15  8.276727e+08           -0.137022             -1.314167e+08  2022
# 16  4.456471e+08           -0.239909             -1.406603e+08  2022
# 17  4.117729e+08            6.209818              3.546601e+08  2022
# 18  2.215357e+09            0.407032              6.408676e+08  2022
# 19  5.809053e+06                 NaN                       NaN  2022
# 20  3.061889e+07           -0.798399             -1.212599e+08  2022
# 21  2.823377e+09            0.349548              7.312862e+08  2022
# 22  6.361113e+08                 NaN                       NaN  2022
# 23  6.202682e+06                 NaN                       NaN  2022
# 24  1.671483e+09            0.372603              4.537363e+08  2022
# 25  2.706777e+08           -0.520548             -2.938787e+08  2022
# 26  1.962323e+08           -0.076310             -1.621168e+07  2022
# 27  1.160231e+10            0.345258              2.977712e+09  2022
# 28  3.508218e+08            0.100840              3.213612e+07  2022
# 29  2.402248e+08           -0.126476             -3.478163e+07  2022
# 30  4.299081e+09            0.151688              5.662289e+08  2022
# 31  3.026647e+08            0.517670              1.032374e+08  2022
# 32  2.289589e+09            0.603289              8.615314e+08  2022
# 33  1.969690e+07           -0.237673             -6.140967e+06  2022
# 34  3.675384e+07            0.205425              6.263483e+06  2022
# 35  1.155944e+08                 NaN                       NaN  2022
# 36  5.751746e+08            0.213879              1.013428e+08  2022

# %%
df2022=df2022.sort_values(by='Trade Value', ascending=False)
df2015=df2015.sort_values(by='Trade Value', ascending=False)
df2022.rename(columns={'Trade Value':'Trade Value 2022'}, inplace=True)
df2015.rename(columns={'Trade Value':'Trade Value 2015'}, inplace=True)
del df2022['Year']
del df2015['Year']
df2022
# Out:
#         Continent Continent ID               Country Country ID ISO 3  \
# 27         Europe           eu                 Italy      euita   ita
# 8            Asia           as           South Korea      askor   kor
# 30         Europe           eu           Netherlands      eunld   nld
# 3            Asia           as                 China      aschn   chn
# 11           Asia           as                Turkey      astur   tur
# 21         Europe           eu                France      eufra   fra
# 32         Europe           eu               Romania      eurou   rou
# 18         Europe           eu                 Spain      euesp   esp
# 9            Asia           as             Singapore      assgp   sgp
# 4            Asia           as                 India      asind   ind
# 24         Europe           eu                Greece      eugrc   grc
# 13         Europe           eu               Austria      euaut   aut
# 15         Europe           eu           Switzerland      euche   che
# 5            Asia           as                Israel      asisr   isr
# 22         Europe           eu        United Kingdom      eugbr   gbr
# 36  North America           na         United States      nausa   usa
# 2            Asia           as                Brunei      asbrn   brn
# 16         Europe           eu               Czechia      eucze   cze
# 17         Europe           eu               Germany      eudeu   deu
# 28         Europe           eu             Lithuania      eultu   ltu
# 31         Europe           eu                Poland      eupol   pol
# 25         Europe           eu               Croatia      euhrv   hrv
# 0            Asia           as  United Arab Emirates      asare   are
# 29         Europe           eu                 Malta      eumlt   mlt
# 26         Europe           eu               Hungary      euhun   hun
# 35  North America           na                Panama      napan   pan
# 6            Asia           as                 Japan      asjpn   jpn
# 1            Asia           as            Azerbaijan      asaze   aze
# 12           Asia           as            Uzbekistan      asuzb   uzb
# 14         Europe           eu              Bulgaria      eubgr   bgr
# 34         Europe           eu              Slovakia      eusvk   svk
# 10           Asia           as              Thailand      astha   tha
# 20         Europe           eu               Finland      eufin   fin
# 33         Europe           eu                Russia      eurus   rus
# 23         Europe           eu             Gibraltar      eugib   gib
# 19         Europe           eu               Estonia      euest   est
# 7            Asia           as            Kyrgyzstan      askgz   kgz
#
#     Trade Value 2022  Trade Value Growth  Trade Value Growth Value
# 27      1.160231e+10            0.345258              2.977712e+09
# 8       4.393006e+09            1.586222              2.694386e+09
# 30      4.299081e+09            0.151688              5.662289e+08
# 3       4.102964e+09            1.202370              2.239987e+09
# 11      2.898124e+09            0.737171              1.229823e+09
# 21      2.823377e+09            0.349548              7.312862e+08
# 32      2.289589e+09            0.603289              8.615314e+08
# 18      2.215357e+09            0.407032              6.408676e+08
# 9       1.811498e+09            0.631146              7.009302e+08
# 4       1.697604e+09            0.111243              1.699414e+08
# 24      1.671483e+09            0.372603              4.537363e+08
# 13      1.430789e+09            0.008821              1.251054e+07
# 15      8.276727e+08           -0.137022             -1.314167e+08
# 5       7.765701e+08            2.868801              5.758438e+08
# 22      6.361113e+08                 NaN                       NaN
# 36      5.751746e+08            0.213879              1.013428e+08
# 2       5.396681e+08           -0.391758             -3.475908e+08
# 16      4.456471e+08           -0.239909             -1.406603e+08
# 17      4.117729e+08            6.209818              3.546601e+08
# 28      3.508218e+08            0.100840              3.213612e+07
# 31      3.026647e+08            0.517670              1.032374e+08
# 25      2.706777e+08           -0.520548             -2.938787e+08
# 0       2.496225e+08            2.689552              1.819659e+08
# 29      2.402248e+08           -0.126476             -3.478163e+07
# 26      1.962323e+08           -0.076310             -1.621168e+07
# 35      1.155944e+08                 NaN                       NaN
# 6       7.867198e+07            0.058120              4.321230e+06
# 1       7.475568e+07                 NaN                       NaN
# 12      5.646707e+07            0.963288              2.770559e+07
# 14      5.017184e+07           -0.825056             -2.366161e+08
# 34      3.675384e+07            0.205425              6.263483e+06
# 10      3.523136e+07                 NaN                       NaN
# 20      3.061889e+07           -0.798399             -1.212599e+08
# 33      1.969690e+07           -0.237673             -6.140967e+06
# 23      6.202682e+06                 NaN                       NaN
# 19      5.809053e+06                 NaN                       NaN
# 7       5.762250e+05            0.874585              2.688370e+05

# %%
df=pd.merge(df2015,df2022, how='outer')

# %%
df['Porcentaje']=(df['Trade Value 2022']*100/df['Trade Value 2015'])
df=df.sort_values(by='Trade Value 2022', ascending=False)
df=df.head()
#df['Trade Value 2022']=df['Trade Value 2022'].apply(lambda x: f'{x:,.2f}')
#df['Trade Value 2015']=df['Trade Value 2015'].apply(lambda x: f'{x:,.2f}')
df
# Out:
#    Continent Continent ID      Country Country ID ISO 3  Trade Value 2015  \
# 29    Europe           eu        Italy      euita   ita      7.892581e+09
# 10      Asia           as  South Korea      askor   kor      6.676202e+08
# 33    Europe           eu  Netherlands      eunld   nld      3.734939e+09
# 2       Asia           as        China      aschn   chn      2.046049e+09
# 12      Asia           as       Turkey      astur   tur      3.338926e+08
#
#     Trade Value 2022  Trade Value Growth  Trade Value Growth Value  Porcentaje
# 29      1.160231e+10            0.345258              2.977712e+09  147.002759
# 10      4.393006e+09            1.586222              2.694386e+09  658.009680
# 33      4.299081e+09            0.151688              5.662289e+08  115.104469
# 2       4.102964e+09            1.202370              2.239987e+09  200.531101
# 12      2.898124e+09            0.737171              1.229823e+09  867.981062

# %%
x=df['Country'].head()
y=df['Porcentaje'].head()
y2=df['Trade Value 2022'].head()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(121)
plt.bar(x,y2, width=0.5, label='Exportaciones en dólares')
plt.xticks(rotation=45)
plt.title('Destino de exportaciones de petróleo crudo en 2022')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.legend(loc=0)
plt.xlabel('País')
plt.ylabel('Exportaciones')
plt.subplot(122)
plt.bar(x,y, width=0.5, color='g', label='Porcentaje de crecimiento')
plt.xlabel('País')
plt.ylabel('Porcentaje de crecimiento')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.legend(loc=0)
plt.title('Crecimiento de las exportaciones de petróleo entre 2015 y 2022')
plt.tight_layout()
plt.show()

# %%
dfb2000=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2000.csv', sep=',')
dfb2005=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2005.csv', sep=',')
dfb2010=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2010.csv', sep=',')
dfb2015=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2015.csv', sep=',')
dfb2020=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2020.csv', sep=',')
dfb2022=pd.read_csv('https://raw.githubusercontent.com/Sajerez/Portfolio/refs/heads/main/Gr%C3%A1ficos%20comercio%20Kazakst%C3%A1n/dataframes/a2022.csv', sep=',')
dfb2022
# Out:
#     Continent ID      Continent Country ID        Country ISO 3  Trade Value
# 0             af         Africa      afago         Angola   ago      59543.0
# 1             af         Africa      afben          Benin   ben    4811769.0
# 2             af         Africa      afbfa   Burkina Faso   bfa       8968.0
# 3             af         Africa      afciv  Cote d'Ivoire   civ      44405.0
# 4             af         Africa      afcmr       Cameroon   cmr      67171.0
# ..           ...            ...        ...            ...   ...          ...
# 141           sa  South America      saecu        Ecuador   ecu     520363.0
# 142           sa  South America      saguy         Guyana   guy      80786.0
# 143           sa  South America      saper           Peru   per     662439.0
# 144           sa  South America      sapry       Paraguay   pry   16361711.0
# 145           sa  South America      saury        Uruguay   ury    4056418.0
#
# [146 rows x 6 columns]

# %%
dfb2022.rename(columns={'Trade Value':'Trade Value 2022'}, inplace=True)
dfb2020.rename(columns={'Trade Value':'Trade Value 2020'}, inplace=True)
dfb2015.rename(columns={'Trade Value':'Trade Value 2015'}, inplace=True)
dfb2010.rename(columns={'Trade Value':'Trade Value 2010'}, inplace=True)
dfb2005.rename(columns={'Trade Value':'Trade Value 2005'}, inplace=True)
dfb2000.rename(columns={'Trade Value':'Trade Value 2000'}, inplace=True)

# %%
dfb=pd.merge(dfb2000,dfb2005, how='outer')
dfb=pd.merge(dfb,dfb2010, how='outer')
dfb=pd.merge(dfb,dfb2015, how='outer')
dfb=pd.merge(dfb,dfb2020, how='outer')
dfb=pd.merge(dfb,dfb2022, how='outer')

# %%
dfb=dfb.sort_values(by='Trade Value 2022', ascending=False)
dfb.set_index('Country')
# Out:
#                   Continent ID      Continent Country ID ISO 3  \
# Country
# China                       as           Asia      aschn   chn
# Italy                       eu         Europe      euita   ita
# Russia                      eu         Europe      eurus   rus
# United Kingdom              eu         Europe      eugbr   gbr
# Netherlands                 eu         Europe      eunld   nld
# ...                        ...            ...        ...   ...
# American Samoa              oc        Oceania      ocasm   asm
# New Caledonia               oc        Oceania      ocncl   ncl
# Solomon Islands             oc        Oceania      ocslb   slb
# Wallis and Futuna           oc        Oceania      ocwlf   wlf
# Venezuela                   sa  South America      saven   ven
#
#                    Trade Value 2000  Trade Value 2005  Trade Value 2010  \
# Country
# China                  8.137787e+08      2.701531e+09      9.999287e+09
# Italy                  6.803567e+08      3.888645e+09      8.623065e+09
# Russia                 1.963350e+09      2.945623e+09      3.005454e+09
# United Kingdom         3.154293e+08      3.544877e+08      1.389181e+09
# Netherlands            8.768558e+07      8.709674e+08      4.167996e+09
# ...                             ...               ...               ...
# American Samoa                  NaN               NaN      5.034100e+04
# New Caledonia                   NaN      4.437100e+04               NaN
# Solomon Islands        1.255000e+06               NaN               NaN
# Wallis and Futuna      4.760000e+04               NaN               NaN
# Venezuela                       NaN      5.914100e+04      2.070400e+04
#
#                    Trade Value 2015  Trade Value 2020  Trade Value 2022
# Country
# China                  5.503976e+09      9.538154e+09      1.338448e+10
# Italy                  8.203306e+09      6.759673e+09      1.244859e+10
# Russia                 4.692153e+09      5.295630e+09      8.779781e+09
# United Kingdom         8.708308e+08      7.910780e+08      8.006287e+09
# Netherlands            4.955752e+09      3.139220e+09      5.477253e+09
# ...                             ...               ...               ...
# American Samoa                  NaN               NaN               NaN
# New Caledonia          2.240000e+02               NaN               NaN
# Solomon Islands                 NaN               NaN               NaN
# Wallis and Futuna               NaN               NaN               NaN
# Venezuela              2.678832e+06               NaN               NaN
#
# [175 rows x 10 columns]

# %%
dfb=dfb.head()
#dfb=dfb.drop(columns=['Continent ID','Continent', 'Country ID','ISO 3'])
y=dfb.head()
y.set_index('Country', inplace=True)
y
# Out:
#                Continent ID Continent Country ID ISO 3  Trade Value 2000  \
# Country
# China                    as      Asia      aschn   chn      8.137787e+08
# Italy                    eu    Europe      euita   ita      6.803567e+08
# Russia                   eu    Europe      eurus   rus      1.963350e+09
# United Kingdom           eu    Europe      eugbr   gbr      3.154293e+08
# Netherlands              eu    Europe      eunld   nld      8.768558e+07
#
#                 Trade Value 2005  Trade Value 2010  Trade Value 2015  \
# Country
# China               2.701531e+09      9.999287e+09      5.503976e+09
# Italy               3.888645e+09      8.623065e+09      8.203306e+09
# Russia              2.945623e+09      3.005454e+09      4.692153e+09
# United Kingdom      3.544877e+08      1.389181e+09      8.708308e+08
# Netherlands         8.709674e+08      4.167996e+09      4.955752e+09
#
#                 Trade Value 2020  Trade Value 2022
# Country
# China               9.538154e+09      1.338448e+10
# Italy               6.759673e+09      1.244859e+10
# Russia              5.295630e+09      8.779781e+09
# United Kingdom      7.910780e+08      8.006287e+09
# Netherlands         3.139220e+09      5.477253e+09

# %%
meses = ["2000", "2005", "2010", "2015", "2020", "2022"]
countries = dfb["Country"]
x = np.arange(len(countries))  
ancho = 0.15 

plt.bar(x - 2 * ancho, dfb["Trade Value 2000"], ancho, label='2000')
plt.bar(x - ancho, dfb["Trade Value 2005"], ancho, label='2005')
plt.bar(x, dfb["Trade Value 2010"], ancho, label='2010')
plt.bar(x + ancho, dfb["Trade Value 2015"], ancho, label='2015')
plt.bar(x + 2 * ancho, dfb["Trade Value 2020"], ancho, label='2020')
plt.bar(x + 3 * ancho, dfb["Trade Value 2022"], ancho, label='2022')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.xlabel('País')
plt.ylabel('Cantidad de exportaciones en millones de dólares')
plt.title('Cantidad de exportaciones por país y año')
plt.xticks(x, countries, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Datos conseguidos de un paper
x = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
y = [19.177, 20.789, 20.260, 19.272, 13.323, 10.458, 13.973, 16.142, 14.534, 9.770]
len=len(x)

# %%
mpl.rcParams['font.family'] = 'serif'

# %%
plt.figure(figsize=(12,6))
plt.plot(x,y, label='Exportaciones en millones de euros')
plt.legend(loc=0)
plt.plot(x,y,'ro')
plt.xlabel('Año')
plt.ylabel('Exportaciones en millones de dolares')
plt.title('Exportaciones kazajas hacia la UE de 2011 a 2020')
plt.xticks(np.arange(2011,2021,1))
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
